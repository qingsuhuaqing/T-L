# %%
# !nvidia-smi
# Out:
# Mon Jan 26 03:40:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os

# 1. 定义工作目录 (使用 Colab 的临时空间，速度最快)
project_root = "/content/Time-LLM-Project"

# 2. 拉取 GitHub 代码
# 如果目录不存在，就克隆；如果存在，就更新
if not os.path.exists(project_root):
    print("正在克隆仓库...")
    # !git clone https://github.com/qingsuhuaqing/T-L.git {project_root}
else:
    print("仓库已存在，正在更新代码...")
    # %cd {project_root}
    # !git pull

# 3. 进入项目目录
# %cd {project_root}
print(f"当前工作目录: {os.getcwd()}")
# Out:
# 正在克隆仓库...
# Cloning into '/content/Time-LLM-Project'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 135 (delta 27), reused 130 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 7.56 MiB | 14.07 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/Time-LLM-Project
# 当前工作目录: /content/Time-LLM-Project

# %%
print("正在安装环境依赖，请稍候...")
# -q 表示安静模式，减少刷屏；--upgrade 确保版本兼容
# !pip install -r requirements.txt -q
# !pip install -U "huggingface_hub[cli]" -q  # 确保有下载模型的工具

print("环境配置完成！✅")
# Out:
# 正在安装环境依赖，请稍候...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 45.1 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 82.8 MB/s eta 0:00:0000:010:01m
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# WARNING: huggingface-hub 1.3.3 does not provide the extra 'cli'
# ...

# %%
# 1. 强制升级关键库，解决编译错误和版本冲突
# 我们直接安装最新版的 transformers, accelerate 和 huggingface_hub
print("正在修复环境依赖冲突... 🚑")
# !pip install --upgrade transformers accelerate sentencepiece protobuf huggingface_hub -q

# 2. 再次尝试安装项目特定的其他依赖 (忽略已安装的)
# 这一步是为了补齐项目里用到的小众库 (比如 pandas, numpy 等)
print("正在补齐其他依赖... 🔧")
# !pip install -r requirements.txt --no-deps -q

print("修复完成！再次尝试检查环境... ✅")
# 检查一下显卡和库是否都在
import torch
import transformers
print(f"PyTorch version: {torch.__version__}")
print(f"Transformers version: {transformers.__version__}")
# !nvidia-smi
# Out:
# 正在修复环境依赖冲突... 🚑
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.3/323.3 kB 7.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 26.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.4 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.4 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.4 which is incompatible.
# 正在补齐其他依赖... 🔧
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
